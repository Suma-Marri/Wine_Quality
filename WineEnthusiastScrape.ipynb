# %% [raw]
# !pip install fake_useragent
# !pip install re

# %% [markdown]
# ## Initialize

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import re
import time
import random
import datetime

# %%
ua = UserAgent()

# %% [markdown]
# ## Find the total number of pages

# %%
def total_pages(url):
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(url,headers=headers)
    soup = BeautifulSoup(response.content,'lxml')
    pages = soup.find('div',class_="pagination").find_all('li')[-1].find('a').get_text()
    pages = int(pages)    # 'pages' is the total number of pages
    return pages

# %% [markdown]
# ## Function to parse each item's page

# %%
def help_retrieve(dic,key):
    try:
        return dic[key]
    except KeyError:
        return np.NaN

# %%
def parse_item(url):
    item_url = 'https://www.winemag.com/buying-guide' + url
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(item_url,headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content,'lxml')
        try:
            description = soup.find('p',class_='description').get_text()
        except AttributeError:
            description = np.NaN
        try:
            taster = soup.find('span',class_='taster-area').get_text()
        except AttributeError:
            taster = np.NaN

        info_list = soup.find_all('li',class_='row')
        info_dict = dict()

        for element in info_list:
            tag = element.find_all('div')[0].get_text().strip()
            value = element.find_all('div')[1].get_text().strip()
            info_dict[tag] = value

        designation = help_retrieve(info_dict,"Designation")
        variety = help_retrieve(info_dict,"Variety")
        appellation = help_retrieve(info_dict,"Appellation")
        winery = help_retrieve(info_dict,"Winery")
        alcohol = help_retrieve(info_dict,"Alcohol")
        bottle_size = help_retrieve(info_dict,"Bottle Size")
        category = help_retrieve(info_dict,"Category")
        importer = help_retrieve(info_dict,"Importer")
        date_published = help_retrieve(info_dict,"Date Published")
        user_avg_rating = help_retrieve(info_dict,"User Avg Rating")

        if user_avg_rating == 'Not rated yet [Add Your Review]':
            user_avg_rating = np.NaN

        related_items = soup.find_all('li',class_='review-item')
        related_items = [element.find('a').get('data-review-id') for element in related_items]    # related_items holds a list of related items' ids

        return (description,taster,designation,variety,appellation,winery,alcohol,bottle_size,\
                category,importer,date_published,user_avg_rating,related_items)
    else:
        print(f"{item_url} request failed! Status code: {response.status_code}. Skip it.")
        raise RuntimeError

# %% [markdown]
# ## Function to parse each page

# %%
# only store the ending of each item's url to save memory, because the former parts are the same for all
pattern = re.compile(r'https://www.winemag.com/buying-guide(?P<ending>.*)')

# request and parse each page
# return a list with items in this page as tuples inside
def parse_page(base_url,i):
    url = re.sub(r"page=\d+",f"page={i}",base_url)  
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(url,headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content,'lxml')
        li = soup.find_all('li',class_="review-item")
        page = list()

        for element in li:
            try:
                name = element.find('h3').get_text()
                rating = element.find('span',class_="rating").find('strong').get_text()
                price = element.find('span',class_="price").get_text()
                price = price.replace('$','')
            except AttributeError:
                print(f"Some items are missed from page {i}: {url}. Skip it.")
                continue
            try:
                price = float(price)
            except ValueError:
                price = np.NaN
            item_url = element.find('a',class_="review-listing row").get('href')
            item_url = pattern.search(item_url).group('ending')
            item_id = element.find('a',class_="review-listing row").get('data-review-id')
            try:
                details = parse_item(item_url)
            except RuntimeError:
                details = (np.NaN,)*13
            all_info = (item_id,name,rating,price,item_url) + details
            page.append(all_info)
            
        return page
    else:
        print(f"Page #{i} request failed! Status code: {response.status_code}. Skip it.")
        raise RuntimeError()

# %% [markdown]
# ## Scrape all the pages

# %%
def scrape_all(url):
    result = list()
    start = datetime.datetime.now()
    pages = total_pages(url)

    for i in range(1,pages+1):
        try:
            result.extend(parse_page(url,i))
            time.sleep(random.random())
        except RuntimeError:
            pass
        except:
            print(r"No worry! I'm still working :)")
        finally:
            if i%10 == 0:
                print(f"Process overview: {i} pages have been scraped...")

    end = datetime.datetime.now()
    interval = (end - start).total_seconds()
    hour = int(interval // 3600)
    minute = int((interval % 3600) // 60)
    second = int((interval % 3600) % 60)
    print(f"For base url: {url}")
    print(f"Scraping has been done in {hour}h {minute}min {second}s. Congrats!")
    
    return result

# %%
def scrape_url_list(urls, file_name="PortugueseWines_WineEnthusiastScrape.csv"):
    result = list()
    
    for url in urls:
        try:
            print(f"Begin scraping from base url: {url}")
            result.extend(scrape_all(url))
        except:
            print(f"Scraping from base url: {url} FAILED! Going to the next one...")
            continue
        
    df = pd.DataFrame(result,columns=['id','name','rating','price','item_url','description','taster',\
                                      'designation','variety','appellation','winery','alcohol','bottle_size',\
                                        'category','importer','date_published','user_avg_rating','related_items'])
    df.to_csv(file_name,encoding='utf-8')
    
    return df

# %%
urls = ['https://www.winemag.com/?s=&drink_type=wine&country=Portugal&page=1'
       ]

# %% [markdown]
# ## Begin scraping!

# %%
df = scrape_url_list(urls)
# Out:
# Begin scraping from base url: https://www.winemag.com/?s=&drink_type=wine&country=Portugal&page=1
# Process overview: 10 pages have been scraped...
# Process overview: 20 pages have been scraped...
# Process overview: 30 pages have been scraped...
# Process overview: 40 pages have been scraped...
# Process overview: 50 pages have been scraped...
# Process overview: 60 pages have been scraped...
# Page #66 request failed! Status code: 502. Skip it.
# Process overview: 70 pages have been scraped...
# Page #80 request failed! Status code: 404. Skip it.
# Process overview: 80 pages have been scraped...
# Process overview: 90 pages have been scraped...
# Process overview: 100 pages have been scraped...
# Process overview: 110 pages have been scraped...
# Process overview: 120 pages have been scraped...
# Process overview: 130 pages have been scraped...
# Process overview: 140 pages have been scraped...
# Process overview: 150 pages have been scraped...
# Process overview: 160 pages have been scraped...
# Process overview: 170 pages have been scraped...
# Process overview: 180 pages have been scraped...
# Process overview: 190 pages have been scraped...
# Process overview: 200 pages have been scraped...
# Process overview: 210 pages have been scraped...
# Process overview: 220 pages have been scraped...
# Process overview: 230 pages have been scraped...
# Process overview: 240 pages have been scraped...
# Process overview: 250 pages have been scraped...
# Page #260 request failed! Status code: 404. Skip it.
# Process overview: 260 pages have been scraped...
# Process overview: 270 pages have been scraped...
# Process overview: 280 pages have been scraped...
# Process overview: 290 pages have been scraped...
# Process overview: 300 pages have been scraped...
# Process overview: 310 pages have been scraped...
# Process overview: 320 pages have been scraped...
# Page #329 request failed! Status code: 404. Skip it.
# Page #330 request failed! Status code: 404. Skip it.
# Process overview: 330 pages have been scraped...
# Page #331 request failed! Status code: 404. Skip it.
# Page #332 request failed! Status code: 404. Skip it.
# Process overview: 340 pages have been scraped...
# Process overview: 350 pages have been scraped...
# Process overview: 360 pages have been scraped...
# Process overview: 370 pages have been scraped...
# Process overview: 380 pages have been scraped...
# https://www.winemag.com/buying-guide/casa-da-passarella-2017-villa-oliveira-vinha-das-pedras-altas-red-dao/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/adega-de-cantanhede-2017-marques-de-marialva-reserva-arinto-bairrada/ request failed! Status code: 502. Skip it.
# Process overview: 390 pages have been scraped...
# https://www.winemag.com/buying-guide/j-portugal-ramos-2019-marques-de-borba-colheita-white-alentejo/ request failed! Status code: 502. Skip it.
# Process overview: 400 pages have been scraped...
# Process overview: 410 pages have been scraped...
# Process overview: 420 pages have been scraped...
# Process overview: 430 pages have been scraped...
# Process overview: 440 pages have been scraped...
# Process overview: 450 pages have been scraped...
# Process overview: 460 pages have been scraped...
# Process overview: 470 pages have been scraped...
# Process overview: 480 pages have been scraped...
# Process overview: 490 pages have been scraped...
# Process overview: 500 pages have been scraped...
# Process overview: 510 pages have been scraped...
# Process overview: 520 pages have been scraped...
# Process overview: 530 pages have been scraped...
# Process overview: 540 pages have been scraped...
# Process overview: 550 pages have been scraped...
# Process overview: 560 pages have been scraped...
# Process overview: 570 pages have been scraped...
# Process overview: 580 pages have been scraped...
# Process overview: 590 pages have been scraped...
# Process overview: 600 pages have been scraped...
# Process overview: 610 pages have been scraped...
# Process overview: 620 pages have been scraped...
# Process overview: 630 pages have been scraped...
# Process overview: 640 pages have been scraped...
# Process overview: 650 pages have been scraped...
# Process overview: 660 pages have been scraped...
# Process overview: 670 pages have been scraped...
# Process overview: 680 pages have been scraped...
# Process overview: 690 pages have been scraped...
# https://www.winemag.com/buying-guide/quinta-das-arcas-2017-arca-nova-alvarinho-minho-300371/ request failed! Status code: 502. Skip it.
# Process overview: 700 pages have been scraped...
# Process overview: 710 pages have been scraped...
# Process overview: 720 pages have been scraped...
# https://www.winemag.com/buying-guide/palato-do-coa-2013-reserva-do-coa-red-douro/ request failed! Status code: 502. Skip it.
# Process overview: 730 pages have been scraped...
# Process overview: 740 pages have been scraped...
# Process overview: 750 pages have been scraped...
# https://www.winemag.com/buying-guide/romana-vini-2016-quinta-da-escusa-harvest-white-tejo/ request failed! Status code: 502. Skip it.
# Process overview: 760 pages have been scraped...
# Process overview: 770 pages have been scraped...
# Process overview: 780 pages have been scraped...
# Process overview: 790 pages have been scraped...
# Process overview: 800 pages have been scraped...
# Process overview: 810 pages have been scraped...
# https://www.winemag.com/buying-guide/quinta-da-lagoalva-de-cima-2017-lagoalva-vinho-branco-white-tejo/ request failed! Status code: 502. Skip it.
# Process overview: 820 pages have been scraped...
# Process overview: 830 pages have been scraped...
# Process overview: 840 pages have been scraped...
# Process overview: 850 pages have been scraped...
# Process overview: 860 pages have been scraped...
# Process overview: 870 pages have been scraped...
# Process overview: 880 pages have been scraped...
# Process overview: 890 pages have been scraped...
# Process overview: 900 pages have been scraped...
# Process overview: 910 pages have been scraped...
# Process overview: 920 pages have been scraped...
# Process overview: 930 pages have been scraped...
# Process overview: 940 pages have been scraped...
# Process overview: 950 pages have been scraped...
# Process overview: 960 pages have been scraped...
# Process overview: 970 pages have been scraped...
# Process overview: 980 pages have been scraped...
# https://www.winemag.com/buying-guide/quinta-do-sagrado-2015-sagrado-rose-douro/ request failed! Status code: 502. Skip it.
# Process overview: 990 pages have been scraped...
# Process overview: 1000 pages have been scraped...
# Process overview: 1010 pages have been scraped...
# Process overview: 1020 pages have been scraped...
# Process overview: 1030 pages have been scraped...
# Process overview: 1040 pages have been scraped...
# Process overview: 1050 pages have been scraped...
# Process overview: 1060 pages have been scraped...
# Process overview: 1070 pages have been scraped...
# Process overview: 1080 pages have been scraped...
# Process overview: 1090 pages have been scraped...
# Process overview: 1100 pages have been scraped...
# Process overview: 1110 pages have been scraped...
# Process overview: 1120 pages have been scraped...
# Process overview: 1130 pages have been scraped...
# https://www.winemag.com/buying-guide/quinta-da-raza-2015-dom-diogo-colheita-seleccionada-alvarinho-minho/ request failed! Status code: 502. Skip it.
# Process overview: 1140 pages have been scraped...
# Process overview: 1150 pages have been scraped...
# Process overview: 1160 pages have been scraped...
# https://www.winemag.com/buying-guide/enoport-2013-tonel-22-reserva-red-douro/ request failed! Status code: 502. Skip it.
# Process overview: 1170 pages have been scraped...
# Process overview: 1180 pages have been scraped...
# Process overview: 1190 pages have been scraped...
# Process overview: 1200 pages have been scraped...
# Process overview: 1210 pages have been scraped...
# Process overview: 1220 pages have been scraped...
# Process overview: 1230 pages have been scraped...
# Process overview: 1240 pages have been scraped...
# https://www.winemag.com/buying-guide/casa-da-passarella-2014-o-brazileiro-rose-dao/ request failed! Status code: 502. Skip it.
# Process overview: 1250 pages have been scraped...
# Process overview: 1260 pages have been scraped...
# Process overview: 1270 pages have been scraped...
# Process overview: 1280 pages have been scraped...
# Process overview: 1290 pages have been scraped...
# Process overview: 1300 pages have been scraped...
# Process overview: 1310 pages have been scraped...
# Process overview: 1320 pages have been scraped...
# Process overview: 1330 pages have been scraped...
# Process overview: 1340 pages have been scraped...
# Process overview: 1350 pages have been scraped...
# Process overview: 1360 pages have been scraped...
# Page #1364 request failed! Status code: 502. Skip it.
# Process overview: 1370 pages have been scraped...
# Process overview: 1380 pages have been scraped...
# Process overview: 1390 pages have been scraped...
# Process overview: 1400 pages have been scraped...
# Process overview: 1410 pages have been scraped...
# Process overview: 1420 pages have been scraped...
# Process overview: 1430 pages have been scraped...
# Process overview: 1440 pages have been scraped...
# Process overview: 1450 pages have been scraped...
# Process overview: 1460 pages have been scraped...
# Process overview: 1470 pages have been scraped...
# Process overview: 1480 pages have been scraped...
# Process overview: 1490 pages have been scraped...
# Process overview: 1500 pages have been scraped...
# Process overview: 1510 pages have been scraped...
# Process overview: 1520 pages have been scraped...
# Process overview: 1530 pages have been scraped...
# Process overview: 1540 pages have been scraped...
# Process overview: 1550 pages have been scraped...
# Process overview: 1560 pages have been scraped...
# Process overview: 1570 pages have been scraped...
# Process overview: 1580 pages have been scraped...
# Page #1590 request failed! Status code: 502. Skip it.
# Process overview: 1590 pages have been scraped...
# Process overview: 1600 pages have been scraped...
# Process overview: 1610 pages have been scraped...
# Process overview: 1620 pages have been scraped...
# https://www.winemag.com/buying-guide/aveleda-2012-white-vinho-verde/ request failed! Status code: 502. Skip it.
# Process overview: 1630 pages have been scraped...
# Process overview: 1640 pages have been scraped...
# Process overview: 1650 pages have been scraped...
# Process overview: 1660 pages have been scraped...
# Process overview: 1670 pages have been scraped...
# Process overview: 1680 pages have been scraped...
# Process overview: 1690 pages have been scraped...
# Process overview: 1700 pages have been scraped...
# Process overview: 1710 pages have been scraped...
# Process overview: 1720 pages have been scraped...
# Process overview: 1730 pages have been scraped...
# Process overview: 1740 pages have been scraped...
# Process overview: 1750 pages have been scraped...
# Process overview: 1760 pages have been scraped...
# Process overview: 1770 pages have been scraped...
# https://www.winemag.com/buying-guide/niepoort-nv-ruby-reserve-port-blend-port-port/ request failed! Status code: 502. Skip it.
# Process overview: 1780 pages have been scraped...
# Process overview: 1790 pages have been scraped...
# Process overview: 1800 pages have been scraped...
# Process overview: 1810 pages have been scraped...
# Process overview: 1820 pages have been scraped...
# Process overview: 1830 pages have been scraped...
# Process overview: 1840 pages have been scraped...
# Page #1848 request failed! Status code: 502. Skip it.
# Process overview: 1850 pages have been scraped...
# Process overview: 1860 pages have been scraped...
# Process overview: 1870 pages have been scraped...
# Process overview: 1880 pages have been scraped...
# Process overview: 1890 pages have been scraped...
# Process overview: 1900 pages have been scraped...
# Process overview: 1910 pages have been scraped...
# Process overview: 1920 pages have been scraped...
# Process overview: 1930 pages have been scraped...
# https://www.winemag.com/buying-guide/quinta-chocapalha-2008-portuguese-white-arinto-estremadura/ request failed! Status code: 502. Skip it.
# Process overview: 1940 pages have been scraped...
# https://www.winemag.com/buying-guide/pocas-nv-special-reserve-ruby-port-109631/ request failed! Status code: 403. Skip it.
# https://www.winemag.com/buying-guide/quinta-gaivosa-1999-late-bottled-vintage-port-blend-port-port/ request failed! Status code: 403. Skip it.
# https://www.winemag.com/buying-guide/kopke-2005-late-bottled-vintage-port-blend-port-port/ request failed! Status code: 403. Skip it.
# Page #1946 request failed! Status code: 403. Skip it.
# Page #1947 request failed! Status code: 403. Skip it.
# Page #1948 request failed! Status code: 403. Skip it.
# Page #1949 request failed! Status code: 403. Skip it.
# Page #1950 request failed! Status code: 403. Skip it.
# Process overview: 1950 pages have been scraped...
# Page #1951 request failed! Status code: 403. Skip it.
# Page #1952 request failed! Status code: 403. Skip it.
# Page #1953 request failed! Status code: 403. Skip it.
# Page #1954 request failed! Status code: 403. Skip it.
# Page #1955 request failed! Status code: 403. Skip it.
# Page #1956 request failed! Status code: 403. Skip it.
# Page #1957 request failed! Status code: 403. Skip it.
# Page #1958 request failed! Status code: 403. Skip it.
# Page #1959 request failed! Status code: 403. Skip it.
# Page #1960 request failed! Status code: 403. Skip it.
# Process overview: 1960 pages have been scraped...
# Page #1961 request failed! Status code: 403. Skip it.
# Page #1962 request failed! Status code: 403. Skip it.
# Page #1963 request failed! Status code: 403. Skip it.
# Page #1964 request failed! Status code: 403. Skip it.
# Page #1965 request failed! Status code: 403. Skip it.
# Page #1966 request failed! Status code: 403. Skip it.
# Page #1967 request failed! Status code: 403. Skip it.
# Page #1968 request failed! Status code: 403. Skip it.
# Page #1969 request failed! Status code: 403. Skip it.
# Page #1970 request failed! Status code: 403. Skip it.
# Process overview: 1970 pages have been scraped...
# Page #1971 request failed! Status code: 403. Skip it.
# Page #1972 request failed! Status code: 403. Skip it.
# Page #1973 request failed! Status code: 403. Skip it.
# Page #1974 request failed! Status code: 403. Skip it.
# Page #1975 request failed! Status code: 403. Skip it.
# Page #1976 request failed! Status code: 403. Skip it.
# Page #1977 request failed! Status code: 403. Skip it.
# Page #1978 request failed! Status code: 403. Skip it.
# Page #1979 request failed! Status code: 403. Skip it.
# Page #1980 request failed! Status code: 403. Skip it.
# Process overview: 1980 pages have been scraped...
# Page #1981 request failed! Status code: 403. Skip it.
# Page #1982 request failed! Status code: 403. Skip it.
# Page #1983 request failed! Status code: 403. Skip it.
# Page #1984 request failed! Status code: 403. Skip it.
# Page #1985 request failed! Status code: 403. Skip it.
# Page #1986 request failed! Status code: 403. Skip it.
# Page #1987 request failed! Status code: 403. Skip it.
# Page #1988 request failed! Status code: 403. Skip it.
# Page #1989 request failed! Status code: 403. Skip it.
# Page #1990 request failed! Status code: 403. Skip it.
# Process overview: 1990 pages have been scraped...
# Page #1991 request failed! Status code: 403. Skip it.
# Page #1992 request failed! Status code: 403. Skip it.
# Page #1993 request failed! Status code: 403. Skip it.
# Page #1994 request failed! Status code: 403. Skip it.
# Page #1995 request failed! Status code: 403. Skip it.
# Page #1996 request failed! Status code: 403. Skip it.
# Page #1997 request failed! Status code: 403. Skip it.
# Page #1998 request failed! Status code: 403. Skip it.
# Page #1999 request failed! Status code: 403. Skip it.
# Page #2000 request failed! Status code: 403. Skip it.
# Process overview: 2000 pages have been scraped...
# Page #2001 request failed! Status code: 403. Skip it.
# Page #2002 request failed! Status code: 403. Skip it.
# Page #2003 request failed! Status code: 403. Skip it.
# Page #2004 request failed! Status code: 403. Skip it.
# Page #2005 request failed! Status code: 403. Skip it.
# Page #2006 request failed! Status code: 403. Skip it.
# Page #2007 request failed! Status code: 403. Skip it.
# Page #2008 request failed! Status code: 403. Skip it.
# Page #2009 request failed! Status code: 403. Skip it.
# Page #2010 request failed! Status code: 403. Skip it.
# Process overview: 2010 pages have been scraped...
# Page #2011 request failed! Status code: 403. Skip it.
# Page #2012 request failed! Status code: 403. Skip it.
# Page #2013 request failed! Status code: 403. Skip it.
# Page #2014 request failed! Status code: 403. Skip it.
# Page #2015 request failed! Status code: 403. Skip it.
# Page #2016 request failed! Status code: 403. Skip it.
# Page #2017 request failed! Status code: 403. Skip it.
# Page #2018 request failed! Status code: 403. Skip it.
# Page #2019 request failed! Status code: 403. Skip it.
# Page #2020 request failed! Status code: 403. Skip it.
# Process overview: 2020 pages have been scraped...
# Page #2021 request failed! Status code: 403. Skip it.
# Page #2022 request failed! Status code: 403. Skip it.
# Page #2023 request failed! Status code: 403. Skip it.
# Page #2024 request failed! Status code: 403. Skip it.
# Page #2025 request failed! Status code: 403. Skip it.
# Page #2026 request failed! Status code: 403. Skip it.
# Page #2027 request failed! Status code: 403. Skip it.
# Page #2028 request failed! Status code: 403. Skip it.
# Page #2029 request failed! Status code: 403. Skip it.
# Page #2030 request failed! Status code: 403. Skip it.
# Process overview: 2030 pages have been scraped...
# Page #2031 request failed! Status code: 403. Skip it.
# Page #2032 request failed! Status code: 403. Skip it.
# Page #2033 request failed! Status code: 403. Skip it.
# Page #2034 request failed! Status code: 403. Skip it.
# Page #2035 request failed! Status code: 403. Skip it.
# Page #2036 request failed! Status code: 403. Skip it.
# Page #2037 request failed! Status code: 403. Skip it.
# Page #2038 request failed! Status code: 403. Skip it.
# Page #2039 request failed! Status code: 403. Skip it.
# Page #2040 request failed! Status code: 403. Skip it.
# Process overview: 2040 pages have been scraped...
# Page #2041 request failed! Status code: 403. Skip it.
# Page #2042 request failed! Status code: 403. Skip it.
# Page #2043 request failed! Status code: 403. Skip it.
# Page #2044 request failed! Status code: 403. Skip it.
# Page #2045 request failed! Status code: 403. Skip it.
# Page #2046 request failed! Status code: 403. Skip it.
# Page #2047 request failed! Status code: 403. Skip it.
# Page #2048 request failed! Status code: 403. Skip it.
# Page #2049 request failed! Status code: 403. Skip it.
# Page #2050 request failed! Status code: 403. Skip it.
# Process overview: 2050 pages have been scraped...
# Page #2051 request failed! Status code: 403. Skip it.
# Page #2052 request failed! Status code: 403. Skip it.
# Page #2053 request failed! Status code: 403. Skip it.
# Page #2054 request failed! Status code: 403. Skip it.
# Page #2055 request failed! Status code: 403. Skip it.
# Page #2056 request failed! Status code: 403. Skip it.
# Page #2057 request failed! Status code: 403. Skip it.
# Page #2058 request failed! Status code: 403. Skip it.
# Page #2059 request failed! Status code: 403. Skip it.
# Page #2060 request failed! Status code: 403. Skip it.
# Process overview: 2060 pages have been scraped...
# Page #2061 request failed! Status code: 403. Skip it.
# Page #2062 request failed! Status code: 403. Skip it.
# Page #2063 request failed! Status code: 403. Skip it.
# Page #2064 request failed! Status code: 403. Skip it.
# Page #2065 request failed! Status code: 403. Skip it.
# Page #2066 request failed! Status code: 403. Skip it.
# Page #2067 request failed! Status code: 403. Skip it.
# Page #2068 request failed! Status code: 403. Skip it.
# Page #2069 request failed! Status code: 403. Skip it.
# Page #2070 request failed! Status code: 403. Skip it.
# Process overview: 2070 pages have been scraped...
# Page #2071 request failed! Status code: 403. Skip it.
# Page #2072 request failed! Status code: 403. Skip it.
# Page #2073 request failed! Status code: 403. Skip it.
# Page #2074 request failed! Status code: 403. Skip it.
# Page #2075 request failed! Status code: 403. Skip it.
# Page #2076 request failed! Status code: 403. Skip it.
# Page #2077 request failed! Status code: 403. Skip it.
# Page #2078 request failed! Status code: 403. Skip it.
# Page #2079 request failed! Status code: 403. Skip it.
# Page #2080 request failed! Status code: 403. Skip it.
# Process overview: 2080 pages have been scraped...
# Page #2081 request failed! Status code: 403. Skip it.
# Page #2082 request failed! Status code: 403. Skip it.
# Page #2083 request failed! Status code: 403. Skip it.
# Page #2084 request failed! Status code: 403. Skip it.
# Page #2085 request failed! Status code: 403. Skip it.
# Page #2086 request failed! Status code: 403. Skip it.
# Page #2087 request failed! Status code: 403. Skip it.
# Page #2088 request failed! Status code: 403. Skip it.
# Page #2089 request failed! Status code: 403. Skip it.
# Page #2090 request failed! Status code: 403. Skip it.
# Process overview: 2090 pages have been scraped...
# Page #2091 request failed! Status code: 403. Skip it.
# Page #2092 request failed! Status code: 403. Skip it.
# Page #2093 request failed! Status code: 403. Skip it.
# Page #2094 request failed! Status code: 403. Skip it.
# Page #2095 request failed! Status code: 403. Skip it.
# Page #2096 request failed! Status code: 403. Skip it.
# Page #2097 request failed! Status code: 403. Skip it.
# Page #2098 request failed! Status code: 403. Skip it.
# Page #2099 request failed! Status code: 403. Skip it.
# Page #2100 request failed! Status code: 403. Skip it.
# Process overview: 2100 pages have been scraped...
# Page #2101 request failed! Status code: 403. Skip it.
# Page #2102 request failed! Status code: 403. Skip it.
# Page #2103 request failed! Status code: 403. Skip it.
# Page #2104 request failed! Status code: 403. Skip it.
# Page #2105 request failed! Status code: 403. Skip it.
# Page #2106 request failed! Status code: 403. Skip it.
# Page #2107 request failed! Status code: 403. Skip it.
# Page #2108 request failed! Status code: 403. Skip it.
# Page #2109 request failed! Status code: 403. Skip it.
# Page #2110 request failed! Status code: 403. Skip it.
# Process overview: 2110 pages have been scraped...
# Page #2111 request failed! Status code: 403. Skip it.
# Page #2112 request failed! Status code: 403. Skip it.
# Page #2113 request failed! Status code: 403. Skip it.
# Page #2114 request failed! Status code: 403. Skip it.
# Page #2115 request failed! Status code: 403. Skip it.
# Page #2116 request failed! Status code: 403. Skip it.
# Page #2117 request failed! Status code: 403. Skip it.
# Page #2118 request failed! Status code: 403. Skip it.
# Page #2119 request failed! Status code: 403. Skip it.
# Page #2120 request failed! Status code: 403. Skip it.
# Process overview: 2120 pages have been scraped...
# Page #2121 request failed! Status code: 403. Skip it.
# Page #2122 request failed! Status code: 403. Skip it.
# Page #2123 request failed! Status code: 403. Skip it.
# Page #2124 request failed! Status code: 403. Skip it.
# Page #2125 request failed! Status code: 403. Skip it.
# Page #2126 request failed! Status code: 403. Skip it.
# Page #2127 request failed! Status code: 403. Skip it.
# Page #2128 request failed! Status code: 403. Skip it.
# Page #2129 request failed! Status code: 403. Skip it.
# Page #2130 request failed! Status code: 403. Skip it.
# Process overview: 2130 pages have been scraped...
# Page #2131 request failed! Status code: 403. Skip it.
# Page #2132 request failed! Status code: 403. Skip it.
# Page #2133 request failed! Status code: 403. Skip it.
# Page #2134 request failed! Status code: 403. Skip it.
# Page #2135 request failed! Status code: 403. Skip it.
# Page #2136 request failed! Status code: 403. Skip it.
# Page #2137 request failed! Status code: 403. Skip it.
# Page #2138 request failed! Status code: 403. Skip it.
# Page #2139 request failed! Status code: 403. Skip it.
# Page #2140 request failed! Status code: 403. Skip it.
# Process overview: 2140 pages have been scraped...
# Page #2141 request failed! Status code: 403. Skip it.
# Page #2142 request failed! Status code: 403. Skip it.
# Page #2143 request failed! Status code: 403. Skip it.
# Page #2144 request failed! Status code: 403. Skip it.
# Page #2145 request failed! Status code: 403. Skip it.
# Page #2146 request failed! Status code: 403. Skip it.
# Page #2147 request failed! Status code: 403. Skip it.
# Page #2148 request failed! Status code: 403. Skip it.
# Page #2149 request failed! Status code: 403. Skip it.
# Page #2150 request failed! Status code: 403. Skip it.
# Process overview: 2150 pages have been scraped...
# Page #2151 request failed! Status code: 403. Skip it.
# Page #2152 request failed! Status code: 403. Skip it.
# Page #2153 request failed! Status code: 403. Skip it.
# Page #2154 request failed! Status code: 403. Skip it.
# Page #2155 request failed! Status code: 403. Skip it.
# Page #2156 request failed! Status code: 403. Skip it.
# Page #2157 request failed! Status code: 403. Skip it.
# Page #2158 request failed! Status code: 403. Skip it.
# Page #2159 request failed! Status code: 403. Skip it.
# Page #2160 request failed! Status code: 403. Skip it.
# Process overview: 2160 pages have been scraped...
# Page #2161 request failed! Status code: 403. Skip it.
# Page #2162 request failed! Status code: 403. Skip it.
# Page #2163 request failed! Status code: 403. Skip it.
# Page #2164 request failed! Status code: 403. Skip it.
# Page #2165 request failed! Status code: 403. Skip it.
# Page #2166 request failed! Status code: 403. Skip it.
# Page #2167 request failed! Status code: 403. Skip it.
# Page #2168 request failed! Status code: 403. Skip it.
# Page #2169 request failed! Status code: 403. Skip it.
# Page #2170 request failed! Status code: 403. Skip it.
# Process overview: 2170 pages have been scraped...
# Page #2171 request failed! Status code: 403. Skip it.
# Page #2172 request failed! Status code: 403. Skip it.
# Page #2173 request failed! Status code: 403. Skip it.
# Page #2174 request failed! Status code: 403. Skip it.
# Page #2175 request failed! Status code: 403. Skip it.
# Page #2176 request failed! Status code: 403. Skip it.
# Page #2177 request failed! Status code: 403. Skip it.
# Page #2178 request failed! Status code: 403. Skip it.
# Page #2179 request failed! Status code: 403. Skip it.
# Page #2180 request failed! Status code: 403. Skip it.
# Process overview: 2180 pages have been scraped...
# Page #2181 request failed! Status code: 403. Skip it.
# Page #2182 request failed! Status code: 403. Skip it.
# Page #2183 request failed! Status code: 403. Skip it.
# Page #2184 request failed! Status code: 403. Skip it.
# Page #2185 request failed! Status code: 403. Skip it.
# Page #2186 request failed! Status code: 403. Skip it.
# Page #2187 request failed! Status code: 403. Skip it.
# Page #2188 request failed! Status code: 403. Skip it.
# Page #2189 request failed! Status code: 403. Skip it.
# Page #2190 request failed! Status code: 403. Skip it.
# Process overview: 2190 pages have been scraped...
# Page #2191 request failed! Status code: 403. Skip it.
# Page #2192 request failed! Status code: 403. Skip it.
# Page #2193 request failed! Status code: 403. Skip it.
# Page #2194 request failed! Status code: 403. Skip it.
# Page #2195 request failed! Status code: 403. Skip it.
# Page #2196 request failed! Status code: 403. Skip it.
# Page #2197 request failed! Status code: 403. Skip it.
# Page #2198 request failed! Status code: 403. Skip it.
# Page #2199 request failed! Status code: 403. Skip it.
# Page #2200 request failed! Status code: 403. Skip it.
# Process overview: 2200 pages have been scraped...
# Page #2201 request failed! Status code: 403. Skip it.
# Page #2202 request failed! Status code: 403. Skip it.
# Page #2203 request failed! Status code: 403. Skip it.
# Page #2204 request failed! Status code: 403. Skip it.
# Page #2205 request failed! Status code: 403. Skip it.
# Page #2206 request failed! Status code: 403. Skip it.
# Page #2207 request failed! Status code: 403. Skip it.
# Page #2208 request failed! Status code: 403. Skip it.
# Page #2209 request failed! Status code: 403. Skip it.
# Page #2210 request failed! Status code: 403. Skip it.
# Process overview: 2210 pages have been scraped...
# Page #2211 request failed! Status code: 403. Skip it.
# Page #2212 request failed! Status code: 403. Skip it.
# Page #2213 request failed! Status code: 403. Skip it.
# Page #2214 request failed! Status code: 403. Skip it.
# Page #2215 request failed! Status code: 403. Skip it.
# Page #2216 request failed! Status code: 403. Skip it.
# Page #2217 request failed! Status code: 403. Skip it.
# Page #2218 request failed! Status code: 403. Skip it.
# Page #2219 request failed! Status code: 403. Skip it.
# Page #2220 request failed! Status code: 403. Skip it.
# Process overview: 2220 pages have been scraped...
# Page #2221 request failed! Status code: 403. Skip it.
# Page #2222 request failed! Status code: 403. Skip it.
# Page #2223 request failed! Status code: 403. Skip it.
# Page #2224 request failed! Status code: 403. Skip it.
# Page #2225 request failed! Status code: 403. Skip it.
# Page #2226 request failed! Status code: 403. Skip it.
# Page #2227 request failed! Status code: 403. Skip it.
# Page #2228 request failed! Status code: 403. Skip it.
# Page #2229 request failed! Status code: 403. Skip it.
# Page #2230 request failed! Status code: 403. Skip it.
# Process overview: 2230 pages have been scraped...
# Page #2231 request failed! Status code: 403. Skip it.
# Page #2232 request failed! Status code: 403. Skip it.
# Page #2233 request failed! Status code: 403. Skip it.
# Page #2234 request failed! Status code: 403. Skip it.
# Page #2235 request failed! Status code: 403. Skip it.
# Page #2236 request failed! Status code: 403. Skip it.
# Page #2237 request failed! Status code: 403. Skip it.
# Page #2238 request failed! Status code: 403. Skip it.
# Page #2239 request failed! Status code: 403. Skip it.
# Page #2240 request failed! Status code: 403. Skip it.
# Process overview: 2240 pages have been scraped...
# Page #2241 request failed! Status code: 403. Skip it.
# Page #2242 request failed! Status code: 403. Skip it.
# Page #2243 request failed! Status code: 403. Skip it.
# Page #2244 request failed! Status code: 403. Skip it.
# Page #2245 request failed! Status code: 403. Skip it.
# Page #2246 request failed! Status code: 403. Skip it.
# Page #2247 request failed! Status code: 403. Skip it.
# Page #2248 request failed! Status code: 403. Skip it.
# Page #2249 request failed! Status code: 403. Skip it.
# Page #2250 request failed! Status code: 403. Skip it.
# Process overview: 2250 pages have been scraped...
# Page #2251 request failed! Status code: 403. Skip it.
# Page #2252 request failed! Status code: 403. Skip it.
# Page #2253 request failed! Status code: 403. Skip it.
# Page #2254 request failed! Status code: 403. Skip it.
# Page #2255 request failed! Status code: 403. Skip it.
# Page #2256 request failed! Status code: 403. Skip it.
# Page #2257 request failed! Status code: 403. Skip it.
# Page #2258 request failed! Status code: 403. Skip it.
# Page #2259 request failed! Status code: 403. Skip it.
# Page #2260 request failed! Status code: 403. Skip it.
# Process overview: 2260 pages have been scraped...
# Page #2261 request failed! Status code: 403. Skip it.
# Page #2262 request failed! Status code: 403. Skip it.
# Page #2263 request failed! Status code: 403. Skip it.
# Page #2264 request failed! Status code: 403. Skip it.
# Page #2265 request failed! Status code: 403. Skip it.
# Page #2266 request failed! Status code: 403. Skip it.
# Page #2267 request failed! Status code: 403. Skip it.
# Page #2268 request failed! Status code: 403. Skip it.
# Page #2269 request failed! Status code: 403. Skip it.
# Page #2270 request failed! Status code: 403. Skip it.
# Process overview: 2270 pages have been scraped...
# Page #2271 request failed! Status code: 403. Skip it.
# Page #2272 request failed! Status code: 403. Skip it.
# Page #2273 request failed! Status code: 403. Skip it.
# Page #2274 request failed! Status code: 403. Skip it.
# Page #2275 request failed! Status code: 403. Skip it.
# Page #2276 request failed! Status code: 403. Skip it.
# Page #2277 request failed! Status code: 403. Skip it.
# Page #2278 request failed! Status code: 403. Skip it.
# Page #2279 request failed! Status code: 403. Skip it.
# Page #2280 request failed! Status code: 403. Skip it.
# Process overview: 2280 pages have been scraped...
# Page #2281 request failed! Status code: 403. Skip it.
# Page #2282 request failed! Status code: 403. Skip it.
# Page #2283 request failed! Status code: 403. Skip it.
# Page #2284 request failed! Status code: 403. Skip it.
# Page #2285 request failed! Status code: 403. Skip it.
# Page #2286 request failed! Status code: 403. Skip it.
# Page #2287 request failed! Status code: 403. Skip it.
# Page #2288 request failed! Status code: 403. Skip it.
# Page #2289 request failed! Status code: 403. Skip it.
# Page #2290 request failed! Status code: 403. Skip it.
# Process overview: 2290 pages have been scraped...
# Page #2291 request failed! Status code: 403. Skip it.
# Page #2292 request failed! Status code: 403. Skip it.
# Page #2293 request failed! Status code: 403. Skip it.
# Page #2294 request failed! Status code: 403. Skip it.
# Page #2295 request failed! Status code: 403. Skip it.
# Page #2296 request failed! Status code: 403. Skip it.
# Page #2297 request failed! Status code: 403. Skip it.
# For base url: https://www.winemag.com/?s=&drink_type=wine&country=Portugal&page=1
# Scraping has been done in 6h 29min 51s. Congrats!

# %%
df
# Out:
#            id                                               name rating  \
# 0      393609   Casa Ferreirinha 2018 Quinta da Leda Red (Douro)     96
# 1      396635  Quinta Vale D. Maria 2019 Vinha do Rio Red (Do...     95
# 2      396563  Quinta do Vallado 2018 Vinha da Granja Red (Do...     95
# 3      396175  Aveleda 2017 Quinta d'Aguieira Touriga Naciona...     94
# 4      396201    Conde Vimioso 2017 Vinha do Convento Red (Tejo)     94
# ...       ...                                                ...    ...
# 11605  109592           Offley 2005 Late Bottled Vintage  (Port)     88
# 11606  109580          Warre's 2000 Late Bottled Vintage  (Port)     88
# 11607  109631              Poças NV Special Reserve Ruby  (Port)     88
# 11608  109577  Quinta da Gaivosa 1999 Late Bottled Vintage  (...     88
# 11609  109589            Kopke 2005 Late Bottled Vintage  (Port)     88
#
#        price                                           item_url  \
# 0       75.0   /casa-ferreirinha-2018-quinta-da-leda-red-douro/
# 1      130.0  /quinta-vale-d-maria-2019-vinha-do-rio-red-douro/
# 2      270.0  /quinta-do-vallado-2018-vinha-da-granja-red-do...
# 3       60.0  /aveleda-2017-quinta-daguieira-touriga-naciona...
# 4       25.0    /conde-vimioso-2017-vinha-do-convento-red-tejo/
# ...      ...                                                ...
# 11605   24.0  /offley-2005-late-bottled-vintage-port-blend-p...
# 11606   62.0  /warres-2000-late-bottled-vintage-port-blend-p...
# 11607   19.0        /pocas-nv-special-reserve-ruby-port-109631/
# 11608    NaN  /quinta-gaivosa-1999-late-bottled-vintage-port...
# 11609   24.0  /kopke-2005-late-bottled-vintage-port-blend-po...
#
#                                              description      taster  \
# 0      \n                      This wine comes from o...  Roger Voss
# 1      \n                      Named after the Rio To...  Roger Voss
# 2      \n                      Thirty-four-old vine v...  Roger Voss
# 3      \n                      The wine, with its ric...  Roger Voss
# 4      \n                      This small-production ...  Roger Voss
# ...                                                  ...         ...
# 11605  \n                      Big, bold fruity wine,...  Roger Voss
# 11606  \n                      A firm wine, dry in st...  Roger Voss
# 11607                                                NaN         NaN
# 11608                                                NaN         NaN
# 11609                                                NaN         NaN
#
#                 designation                           variety  \
# 0            Quinta da Leda                    Portuguese Red
# 1              Vinha do Rio                    Portuguese Red
# 2           Vinha da Granja                    Portuguese Red
# 3         Quinta d'Aguieira  Touriga Nacional, Portuguese Red
# 4         Vinha do Convento                    Portuguese Red
# ...                     ...                               ...
# 11605  Late Bottled Vintage                  Port, Port Blend
# 11606  Late Bottled Vintage                  Port, Port Blend
# 11607                   NaN                               NaN
# 11608                   NaN                               NaN
# 11609                   NaN                               NaN
#
#               appellation                winery alcohol bottle_size  \
# 0         Douro, Portugal      Casa Ferreirinha     14%      750 ml
# 1         Douro, Portugal  Quinta Vale D. Maria   15.5%      750 ml
# 2         Douro, Portugal     Quinta do Vallado   14.5%      750 ml
# 3      Bairrada, Portugal               Aveleda     14%      750 ml
# 4          Tejo, Portugal         Conde Vimioso   14.5%      750 ml
# ...                   ...                   ...     ...         ...
# 11605      Port, Portugal                Offley     N/A      750 ml
# 11606      Port, Portugal               Warre's     N/A      750 ml
# 11607                 NaN                   NaN     NaN         NaN
# 11608                 NaN                   NaN     NaN         NaN
# 11609                 NaN                   NaN     NaN         NaN
#
#           category              importer date_published user_avg_rating  \
# 0              Red           Evaton, Inc       7/1/2022             NaN
# 1              Red           Aveleda Inc       7/1/2022             NaN
# 2              Red  Quintessential Wines       7/1/2022             NaN
# 3              Red           Aveleda Inc       7/1/2022             NaN
# 4              Red    Terroir Selections       7/1/2022             NaN
# ...            ...                   ...            ...             ...
# 11605  Port/Sherry           Evaton, Inc       3/1/2010             NaN
# 11606  Port/Sherry       Vineyard Brands       3/1/2010             NaN
# 11607          NaN                   NaN            NaN             NaN
# 11608          NaN                   NaN            NaN             NaN
# 11609          NaN                   NaN            NaN             NaN
#
#                                           related_items
# 0                              [386828, 384780, 385019]
# 1                              [354536, 354064, 344748]
# 2      [348685, 236440, 393609, 396563, 396635, 393614]
# 3                              [386695, 386538, 384824]
# 4                              [396551, 396166, 396439]
# ...                                                 ...
# 11605                          [393024, 392457, 381592]
# 11606                          [354953, 357536, 358080]
# 11607                                               NaN
# 11608                                               NaN
# 11609                                               NaN
#
# [11610 rows x 18 columns]
