# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
master_df = pd.read_csv('Master_wine.csv')

# %%
master_df
# Out:
#         alcohol   category country  \
# 0          14.0        Red   Spain
# 1          14.8        Red      US
# 2           NaN        Red      US
# 3          13.5        Red   Spain
# 4          14.5        Red   Spain
# ...         ...        ...     ...
# 248353     13.0      White  France
# 248354     12.0  Sparkling  France
# 248355     11.0  Sparkling   Italy
# 248356     12.0  Sparkling  France
# 248357     13.6        Red      US
#
#                                               description  \
# 0       Seductive like a trap, meaning the nose is lus...
# 1       The vineyard is on Atlas Peak. Modern winemaki...
# 2       Has true varietal spice, something we don't al...
# 3       is a nice wine that's at peak maturity. The no...
# 4       Alongside open, hefty berry aromas are bramble...
# ...                                                   ...
# 248353  Rich and creamy, this is a delicious, ripe, an...
# 248354  Pale, almost Provence rosé in color, this frui...
# ...

# %%
#drop colummns 

master_df = master_df.drop(['description', 'designation','subregion',"subsubregion","title",'url','winery'], axis = 1)

# %%
master_df
# Out:
#         alcohol   category country  price  rating          region  \
# 0          14.0        Red   Spain   36.0      87  Northern Spain
# 1          14.8        Red      US   50.0      87      California
# 2           NaN        Red      US   14.0      87      California
# 3          13.5        Red   Spain   26.0      87  Northern Spain
# 4          14.5        Red   Spain   21.0      87  Northern Spain
# ...         ...        ...     ...    ...     ...             ...
# 248353     13.0      White  France   15.0      89    Loire Valley
# 248354     12.0  Sparkling  France   45.0      89       Champagne
# 248355     11.0  Sparkling   Italy   19.0      89          Veneto
# 248356     12.0  Sparkling  France   50.0      89       Champagne
# 248357     13.6        Red      US   35.0      89          Oregon
#
#                   varietal  vintage
# 0              Tempranillo   2004.0
# 1       Cabernet Sauvignon   2003.0
# 2                    Syrah   2004.0
# ...

# %%
#Filter by Country // We only need Portugal

master_df = master_df.query("country == 'Portugal'")

# %%
master_df
# Out:
#         alcohol     category   country  price  rating                region  \
# 1419       20.0  Port/Sherry  Portugal   27.0      83                 Douro
# 1573        NaN          Red  Portugal   15.0      91                   Dão
# 1619        NaN          Red  Portugal    NaN      91                 Douro
# 1630       14.5          Red  Portugal   58.0      91            Alentejano
# 1651       14.5          Red  Portugal   90.0      92            Alentejano
# ...         ...          ...       ...    ...     ...                   ...
# 247216     12.5         Rose  Portugal    9.0      84           Vinho Verde
# 247228     13.0          Red  Portugal   18.0      84                Lisboa
# 247230     14.0          Red  Portugal    NaN      84  Península de Setúbal
# 247231      9.5        White  Portugal    8.0      84           Vinho Verde
# 247234     12.5    Sparkling  Portugal   16.0      85              Bairrada
#
#                     varietal  vintage
# ...

# %%
master_df = master_df.query("category == 'Red'")

# %% [markdown]
# master_df

# %% [markdown]
# master_df

# %%
master_df
# Out:
#         alcohol category   country  price  rating                region  \
# 1573        NaN      Red  Portugal   15.0      91                   Dão
# 1619        NaN      Red  Portugal    NaN      91                 Douro
# 1630       14.5      Red  Portugal   58.0      91            Alentejano
# 1651       14.5      Red  Portugal   90.0      92            Alentejano
# 1667       15.0      Red  Portugal    NaN      93                 Douro
# ...         ...      ...       ...    ...     ...                   ...
# 247175     14.5      Red  Portugal   15.0      84                 Douro
# 247177     14.0      Red  Portugal    9.0      84  Península de Setúbal
# 247214     13.0      Red  Portugal   25.0      84                  Tejo
# 247228     13.0      Red  Portugal   18.0      84                Lisboa
# 247230     14.0      Red  Portugal    NaN      84  Península de Setúbal
#
#                 varietal  vintage
# 1573      Portuguese Red   2003.0
# ...

# %% [markdown]
# # drop NA values for alcohol & rating
#
# red_winedf = master_df.dropna(subset=['alcohol', 'rating'])

# %%
#drop NA values for alcohol & rating

red_winedf = master_df.dropna(subset=['alcohol', 'rating', 'price'])

# %%
red_winedf
red_winedf.describe()
red_winedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3928 entries, 1630 to 247228
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   alcohol   3928 non-null   float64
#  1   category  3928 non-null   object
#  2   country   3928 non-null   object
#  3   price     3928 non-null   float64
#  4   rating    3928 non-null   int64
#  5   region    3928 non-null   object
#  6   varietal  3928 non-null   object
#  7   vintage   3922 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 276.2+ KB

# %%
red_winedf.to_csv('Portuguesereds.csv', index=False)

# %%
red_winedf['alcohol'].describe()
# Out:
# count    3928.000000
# mean       13.856823
# std         3.007878
# min         3.000000
# 25%        13.500000
# 50%        14.000000
# 75%        14.000000
# max        91.000000
# Name: alcohol, dtype: float64

# %%
red_winedf['rating'].describe()
# Out:
# count    3928.000000
# mean       88.885947
# std         2.914052
# min        80.000000
# 25%        87.000000
# 50%        89.000000
# 75%        91.000000
# max       100.000000
# Name: rating, dtype: float64

# %%
red_winedf['price'].describe()
# Out:
# count    3928.000000
# mean       25.293406
# std        25.758343
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        30.000000
# max       550.000000
# Name: price, dtype: float64
