# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
from collections import Counter

# %%
master_df = pd.DataFrame()

for file in os.listdir(os.getcwd()):
    if file.endswith('.csv'): 
        master_df = master_df.append(pd.read_csv(file))

# %%
master_df.to_csv('Master_wine.csv', index=False)

# %%
master_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
path = '/Users/ramonmanrique/Desktop/Wine_Quality/Resources/Master_wine.csv'
master_wine_df1 = pd.read_csv(path)
master_wine_df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
master_wine_df1.describe()
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   25988.000000      25988.000000  25988.000000    25988.000000
# mean        7.215307          0.339666      0.318633        5.443235
# std         1.296359          0.164627      0.145309        4.757529
# min         3.800000          0.080000      0.000000        0.600000
# 25%         6.400000          0.230000      0.250000        1.800000
# 50%         7.000000          0.290000      0.310000        3.000000
# 75%         7.700000          0.400000      0.390000        8.100000
# max        15.900000          1.580000      1.660000       65.800000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  25988.000000         25988.000000          25988.000000  25988.000000
# mean       0.056034            30.525473            115.744728      0.994697
# std        0.035032            17.748288             56.518488      0.002998
# ...

# %%
master_wine_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25988 entries, 0 to 25987
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         25988 non-null  float64
#  1   volatile acidity      25988 non-null  float64
#  2   citric acid           25988 non-null  float64
#  3   residual sugar        25988 non-null  float64
#  4   chlorides             25988 non-null  float64
#  5   free sulfur dioxide   25988 non-null  float64
#  6   total sulfur dioxide  25988 non-null  float64
#  7   density               25988 non-null  float64
#  8   pH                    25988 non-null  float64
#  9   sulphates             25988 non-null  float64
#  10  alcohol               25988 non-null  float64
#  11  quality               25988 non-null  int64
# dtypes: float64(11), int64(1)
# memory usage: 2.4 MB

# %%
# Check for null values
master_wine_df1.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Sort quality values
master_wine_df1['quality'].value_counts().sort_values()
# Out:
# 9       20
# 3      120
# 8      772
# 4      864
# 7     4316
# 5     8552
# 6    11344
# Name: quality, dtype: int64

# %%
# Check value counts
for col in master_wine_df1:
    print(master_wine_df1[col].value_counts(ascending=False), '\n')
# Out:
# 6.80     1416
# 6.60     1308
# 6.40     1220
# 7.00     1128
# 6.90     1116
#          ...
# 3.90        4
# 3.80        4
# 6.45        4
# 4.50        4
# 12.10       4
# Name: fixed acidity, Length: 106, dtype: int64
#
# 0.280    1144
# 0.240    1064
# 0.260    1024
# 0.250     952
# 0.220     940
#          ...
# 0.975       4
# 1.070       4
# 0.950       4
# 1.090       4
# 0.905       4
# Name: volatile acidity, Length: 187, dtype: int64
#
# 0.30    1348
# 0.28    1204
# 0.32    1156
# 0.49    1132
# 0.26    1028
#         ...
# 1.66       4
# 1.23       4
# 0.99       4
# 0.88       4
# 0.75       4
# Name: citric acid, Length: 89, dtype: int64
#
# 2.00     940
# 1.80     912
# 1.60     892
# 1.40     876
# 1.20     780
#         ...
# 12.05      4
# 6.95       4
# 9.55       4
# 20.15      4
# 3.45       4
# Name: residual sugar, Length: 316, dtype: int64
#
# 0.044    824
# 0.036    800
# 0.042    748
# 0.046    740
# 0.040    728
#         ...
# 0.610      4
# ...

# %%
# Show rows and columns of original dataset
master_wine_df1.shape
# Out:
# (25988, 12)

# %%
# Drop Duplicates
# Show rows and columns of updated dataset
master_wine=master_wine_df1.copy()
master_wine.drop_duplicates(subset=None,inplace=True)
master_wine.shape
# Out:
# (5318, 12)

# %%
master_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5318 entries, 0 to 21190
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         5318 non-null   float64
#  1   volatile acidity      5318 non-null   float64
#  2   citric acid           5318 non-null   float64
#  3   residual sugar        5318 non-null   float64
#  4   chlorides             5318 non-null   float64
#  5   free sulfur dioxide   5318 non-null   float64
#  6   total sulfur dioxide  5318 non-null   float64
#  7   density               5318 non-null   float64
#  8   pH                    5318 non-null   float64
#  9   sulphates             5318 non-null   float64
#  10  alcohol               5318 non-null   float64
#  11  quality               5318 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 540.1 KB

# %%
# Correlation heat map

sns.heatmap(master_wine.corr(), annot=True,cmap='PuOr')
plt.show()

# %%
# Split the Data into Training and Testing

# Dividing the dataset in training and testing set
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import metrics 

np.random.seed(0)
df_train,df_test=train_test_split(master_wine,train_size=0.7,test_size=0.3,random_state=100)

# %%
# Create our features
X = master_wine[list(master_wine.columns)[:-1]]

# Create our target
y = master_wine['quality']

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5318.000000       5318.000000  5318.000000     5318.000000
# mean        7.215523          0.344171     0.318522        5.049605
# std         1.319777          0.168264     0.147177        4.500645
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5318.000000          5318.000000           5318.000000  5318.000000
# mean      0.056700            30.030651            114.107841     0.994536
# std       0.036865            17.804264             56.783787     0.002966
# ...

# %%
y.describe()
# Out:
# count    5318.000000
# mean        5.795600
# std         0.879715
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %%
y.value_counts()
# Out:
# 6    2323
# 5    1751
# 7     855
# 4     206
# 8     148
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, stratify=y)

# %%
# Training model info
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3722 entries, 301 to 4863
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3722 non-null   float64
#  1   volatile acidity      3722 non-null   float64
#  2   citric acid           3722 non-null   float64
#  3   residual sugar        3722 non-null   float64
#  4   chlorides             3722 non-null   float64
#  5   free sulfur dioxide   3722 non-null   float64
#  6   total sulfur dioxide  3722 non-null   float64
#  7   density               3722 non-null   float64
#  8   pH                    3722 non-null   float64
#  9   sulphates             3722 non-null   float64
#  10  alcohol               3722 non-null   float64
#  11  quality               3722 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 378.0 KB

# %%
# Testing model info
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1596 entries, 2182 to 4458
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1596 non-null   float64
#  1   volatile acidity      1596 non-null   float64
#  2   citric acid           1596 non-null   float64
#  3   residual sugar        1596 non-null   float64
#  4   chlorides             1596 non-null   float64
#  5   free sulfur dioxide   1596 non-null   float64
#  6   total sulfur dioxide  1596 non-null   float64
#  7   density               1596 non-null   float64
#  8   pH                    1596 non-null   float64
#  9   sulphates             1596 non-null   float64
#  10  alcohol               1596 non-null   float64
#  11  quality               1596 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 162.1 KB

# %%
df_train.shape
# Out:
# (3722, 12)

# %%
df_test.shape
# Out:
# (1596, 12)

# %%
# Pairplot: see both distribution of single variables and relationships between two variables
sns.pairplot(df_train) 
plt.show()

# %%
#Rescaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 301             8.3              0.20         0.35             0.9      0.050
# 1562            7.1              0.34         0.49             1.5      0.027
# 1923            8.2              0.37         0.27             1.7      0.028
# 4871            5.0              0.20         0.40             1.9      0.015
# 117             7.0              0.14         0.40             1.7      0.035
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 301                  12.0                  74.0   0.9920  3.13       0.38
# 1562                 26.0                 126.0   0.9900  3.30       0.33
# 1923                 10.0                  59.0   0.9923  2.97       0.48
# 4871                 20.0                  98.0   0.9897  3.37       0.55
# 117                  16.0                  85.0   0.9911  3.19       0.42
#
#       alcohol  quality
# 301     10.50        6
# ...

# %%
df_train[:]=scaler.fit_transform(df_train[:])
df_train.head()
# Out:
# /Users/ramonmanrique/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/ramonmanrique/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# ...

# %%
# Multi-Variate Analysis
sns.set(rc={'figure.figsize':(11.7,8.27)})
cData_attr = df_train.iloc[:, 0:7]
sns.pairplot(cData_attr, diag_kind='kde')

# %%
#Linear Regression

# fitting linear regression to training data
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
train_pred = regressor.predict(X_train)
print(train_pred)
test_pred = regressor.predict(X_test) 
print(test_pred)
# Out:
# [6.1193394  5.24193087 5.28423466 ... 6.03025892 6.22443038 5.31529109]
# [5.98268515 5.3092465  6.12296124 ... 5.25283228 5.03547734 5.09150876]

# %%
# calculating Root Mean Squared Error (RMSE)
from sklearn.metrics import mean_squared_error

train_rmse = mean_squared_error(train_pred, y_train) ** 0.5
print(train_rmse)
test_rmse = mean_squared_error(test_pred, y_test) ** 0.5
print(test_rmse)
# Out:
# 0.7326245889857266
# 0.7308598243964276

# %%
# rounding off the predicted values for test set
predicted_data = np.round_(test_pred)
print(predicted_data)
# Out:
# [6. 5. 6. ... 5. 5. 5.]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, test_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, test_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, test_pred)))
# Out:
# Mean Absolute Error: 0.5740812851553388
# Mean Squared Error: 0.5341560829167771
# Root Mean Squared Error: 0.7308598243964276

# %%
# Additional Visualizations
# Distributions of the variables / features
df_train.hist(figsize=(20,15),bins=20, color="moccasin")
plt.show()

# %%
df_test.hist(figsize=(20,15),bins=20, color='lightgoldenrodyellow')
plt.show()
