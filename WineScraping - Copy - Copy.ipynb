# %% [raw]
# !pip install fake_useragent
# !pip install re

# %% [markdown]
# ## Initialize

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import re
import time
import random
import datetime

# %%
ua = UserAgent()

# %% [markdown]
# ## Find the total number of pages

# %%
def total_pages(url):
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(url,headers=headers)
    soup = BeautifulSoup(response.content,'lxml')
    pages = soup.find('div',class_="pagination").find_all('li')[-1].find('a').get_text()
    pages = int(pages)    # 'pages' is the total number of pages
    return pages

# %% [markdown]
# ## Function to parse each item's page

# %%
def help_retrieve(dic,key):
    try:
        return dic[key]
    except KeyError:
        return np.NaN

# %%
def parse_item(url):
    item_url = 'https://www.winemag.com/buying-guide' + url
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(item_url,headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content,'lxml')
        try:
            description = soup.find('p',class_='description').get_text()
        except AttributeError:
            description = np.NaN
        try:
            taster = soup.find('span',class_='taster-area').get_text()
        except AttributeError:
            taster = np.NaN

        info_list = soup.find_all('li',class_='row')
        info_dict = dict()

        for element in info_list:
            tag = element.find_all('div')[0].get_text().strip()
            value = element.find_all('div')[1].get_text().strip()
            info_dict[tag] = value

        designation = help_retrieve(info_dict,"Designation")
        variety = help_retrieve(info_dict,"Variety")
        appellation = help_retrieve(info_dict,"Appellation")
        winery = help_retrieve(info_dict,"Winery")
        alcohol = help_retrieve(info_dict,"Alcohol")
        bottle_size = help_retrieve(info_dict,"Bottle Size")
        category = help_retrieve(info_dict,"Category")
        importer = help_retrieve(info_dict,"Importer")
        date_published = help_retrieve(info_dict,"Date Published")
        user_avg_rating = help_retrieve(info_dict,"User Avg Rating")

        if user_avg_rating == 'Not rated yet [Add Your Review]':
            user_avg_rating = np.NaN

        related_items = soup.find_all('li',class_='review-item')
        related_items = [element.find('a').get('data-review-id') for element in related_items]    # related_items holds a list of related items' ids

        return (description,taster,designation,variety,appellation,winery,alcohol,bottle_size,\
                category,importer,date_published,user_avg_rating,related_items)
    else:
        print(f"{item_url} request failed! Status code: {response.status_code}. Skip it.")
        raise RuntimeError

# %% [markdown]
# ## Function to parse each page

# %%
# only store the ending of each item's url to save memory, because the former parts are the same for all
pattern = re.compile(r'https://www.winemag.com/buying-guide(?P<ending>.*)')

# request and parse each page
# return a list with items in this page as tuples inside
def parse_page(base_url,i):
    url = re.sub(r"page=\d+",f"page={i}",base_url)  
    useragent = ua.random    # randomly choose a user-agent
    headers = {'User-Agent':useragent}
    response = requests.get(url,headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content,'lxml')
        li = soup.find_all('li',class_="review-item")
        page = list()

        for element in li:
            try:
                name = element.find('h3').get_text()
                rating = element.find('span',class_="rating").find('strong').get_text()
                price = element.find('span',class_="price").get_text()
                price = price.replace('$','')
            except AttributeError:
                print(f"Some items are missed from page {i}: {url}. Skip it.")
                continue
            try:
                price = float(price)
            except ValueError:
                price = np.NaN
            item_url = element.find('a',class_="review-listing row").get('href')
            item_url = pattern.search(item_url).group('ending')
            item_id = element.find('a',class_="review-listing row").get('data-review-id')
            try:
                details = parse_item(item_url)
            except RuntimeError:
                details = (np.NaN,)*13
            all_info = (item_id,name,rating,price,item_url) + details
            page.append(all_info)
            
        return page
    else:
        print(f"Page #{i} request failed! Status code: {response.status_code}. Skip it.")
        raise RuntimeError()

# %% [markdown]
# ## Scrape all the pages

# %%
def scrape_all(url):
    result = list()
    start = datetime.datetime.now()
    pages = total_pages(url)

    for i in range(1,pages+1):
        try:
            result.extend(parse_page(url,i))
            time.sleep(random.random())
        except RuntimeError:
            pass
        except:
            print(r"No worry! I'm still working :)")
        finally:
            if i%10 == 0:
                print(f"Process overview: {i} pages have been scraped...")

    end = datetime.datetime.now()
    interval = (end - start).total_seconds()
    hour = int(interval // 3600)
    minute = int((interval % 3600) // 60)
    second = int((interval % 3600) % 60)
    print(f"For base url: {url}")
    print(f"Scraping has been done in {hour}h {minute}min {second}s. Congrats!")
    
    return result

# %%
def scrape_url_list(urls, file_name="wineEnthusiast1.csv"):
    result = list()
    
    for url in urls:
        try:
            print(f"Begin scraping from base url: {url}")
            result.extend(scrape_all(url))
        except:
            print(f"Scraping from base url: {url} FAILED! Going to the next one...")
            continue
        
    df = pd.DataFrame(result,columns=['id','name','rating','price','item_url','description','taster',\
                                      'designation','variety','appellation','winery','alcohol','bottle_size',\
                                        'category','importer','date_published','user_avg_rating','related_items'])
    df.to_csv(file_name,encoding='utf-8')
    
    return df

# %%
urls = ['https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=1&search_type=reviews',\
       'https://www.winemag.com/?s=&rating=94.0-97.99&drink_type=wine&page=1&search_type=reviews',\
       'https://www.winemag.com/?s=&rating=80.0-82.99&drink_type=wine&page=1&search_type=reviews',\
       'https://www.winemag.com/?s=&rating=90.0-93.99&price=16.0-25.99,26.0-40.99&drink_type=wine&page=1&search_type=reviews']

# %% [markdown]
# ## Begin scraping!

# %%
df = scrape_url_list(urls)
# Out:
# Begin scraping from base url: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=1&search_type=reviews
# Process overview: 10 pages have been scraped...
# Some items are missed from page 13: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=13&search_type=reviews. Skip it.
# Process overview: 20 pages have been scraped...
# Process overview: 30 pages have been scraped...
# Some items are missed from page 33: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=33&search_type=reviews. Skip it.
# Some items are missed from page 33: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=33&search_type=reviews. Skip it.
# Some items are missed from page 33: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=33&search_type=reviews. Skip it.
# Some items are missed from page 33: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=33&search_type=reviews. Skip it.
# For base url: https://www.winemag.com/?s=&rating=98.0-*&drink_type=wine&page=1&search_type=reviews
# Scraping has been done in 0h 21min 5s. Congrats!
# Begin scraping from base url: https://www.winemag.com/?s=&rating=94.0-97.99&drink_type=wine&page=1&search_type=reviews
# Process overview: 10 pages have been scraped...
# Page #19 request failed! Status code: 502. Skip it.
# Process overview: 20 pages have been scraped...
# Process overview: 30 pages have been scraped...
# Process overview: 40 pages have been scraped...
# Process overview: 50 pages have been scraped...
# Process overview: 60 pages have been scraped...
# Process overview: 70 pages have been scraped...
# Page #80 request failed! Status code: 404. Skip it.
# Process overview: 80 pages have been scraped...
# Process overview: 90 pages have been scraped...
# Process overview: 100 pages have been scraped...
# Process overview: 110 pages have been scraped...
# Process overview: 120 pages have been scraped...
# Page #129 request failed! Status code: 404. Skip it.
# Process overview: 130 pages have been scraped...
# Process overview: 140 pages have been scraped...
# https://www.winemag.com/buying-guide/wine-soul-2017-quinta-da-manoella-vinhas-velhas-red-douro/ request failed! Status code: 502. Skip it.
# Process overview: 150 pages have been scraped...
# Page #155 request failed! Status code: 502. Skip it.
# Process overview: 160 pages have been scraped...
# https://www.winemag.com/buying-guide/tedeschi-2015-la-fabriseria-riserva-amarone-della-valpolicella-classico/ request failed! Status code: 502. Skip it.
# Process overview: 170 pages have been scraped...
# https://www.winemag.com/buying-guide/donum-2018-anderson-valley-pinot-noir-anderson-valley/ request failed! Status code: 502. Skip it.
# Process overview: 180 pages have been scraped...
# Process overview: 190 pages have been scraped...
# Process overview: 200 pages have been scraped...
# https://www.winemag.com/buying-guide/the-joy-fantastic-2018-chardonnay-sta-rita-hills/ request failed! Status code: 502. Skip it.
# Process overview: 210 pages have been scraped...
# https://www.winemag.com/buying-guide/daou-2017-cuvee-lizzy-red-adelaida-district/ request failed! Status code: 502. Skip it.
# Process overview: 220 pages have been scraped...
# Process overview: 230 pages have been scraped...
# Process overview: 240 pages have been scraped...
# Process overview: 250 pages have been scraped...
# Process overview: 260 pages have been scraped...
# Process overview: 270 pages have been scraped...
# Process overview: 280 pages have been scraped...
# https://www.winemag.com/buying-guide/le-ragnaie-2015-vv-brunello-di-montalcino/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/scar-of-the-sea-2017-block-q-bien-nacido-vineyard-old-vine-pinot-noir-santa-maria-valley/ request failed! Status code: 502. Skip it.
# Process overview: 290 pages have been scraped...
# Process overview: 300 pages have been scraped...
# Process overview: 310 pages have been scraped...
# https://www.winemag.com/buying-guide/domaine-saint-prefert-2016-collection-charles-giraud-grenache-mourvedre-chateauneuf-du-pape/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/chateau-de-la-gardine-2016-peur-bleue-red-chateauneuf-du-pape/ request failed! Status code: 502. Skip it.
# Process overview: 320 pages have been scraped...
# Some items are missed from page 328: https://www.winemag.com/?s=&rating=94.0-97.99&drink_type=wine&page=328&search_type=reviews. Skip it.
# Page #329 request failed! Status code: 404. Skip it.
# Page #330 request failed! Status code: 404. Skip it.
# Process overview: 330 pages have been scraped...
# Page #331 request failed! Status code: 404. Skip it.
# Page #332 request failed! Status code: 404. Skip it.
# Process overview: 340 pages have been scraped...
# Process overview: 350 pages have been scraped...
# Process overview: 360 pages have been scraped...
# https://www.winemag.com/buying-guide/crux-2016-zinfandel-russian-river-valley/ request failed! Status code: 502. Skip it.
# Process overview: 370 pages have been scraped...
# Process overview: 380 pages have been scraped...
# No worry! I'm still working :)
# No worry! I'm still working :)
# No worry! I'm still working :)
# Process overview: 390 pages have been scraped...
# No worry! I'm still working :)
# No worry! I'm still working :)
# https://www.winemag.com/buying-guide/quinta-vale-dona-maria-2016-vinha-do-rio-red-douro/ request failed! Status code: 404. Skip it.
# No worry! I'm still working :)
# Process overview: 400 pages have been scraped...
# Process overview: 410 pages have been scraped...
# Page #412 request failed! Status code: 404. Skip it.
# Some items are missed from page 416: https://www.winemag.com/?s=&rating=94.0-97.99&drink_type=wine&page=416&search_type=reviews. Skip it.
# Process overview: 420 pages have been scraped...
# Process overview: 430 pages have been scraped...
# Process overview: 440 pages have been scraped...
# https://www.winemag.com/buying-guide/elvio-cogno-2012-ravera-vigna-elena-barolo/ request failed! Status code: 502. Skip it.
# Process overview: 450 pages have been scraped...
# https://www.winemag.com/buying-guide/moet-chandon-2002-grand-vintage-collection-brut-champagne/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/ramey-2015-hyde-vineyard-chardonnay-carneros/ request failed! Status code: 502. Skip it.
# Process overview: 460 pages have been scraped...
# Process overview: 470 pages have been scraped...
# Page #474 request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/alloro-2015-justina-estate-pinot-noir-chehalem-mountains/ request failed! Status code: 502. Skip it.
# Process overview: 480 pages have been scraped...
# Process overview: 490 pages have been scraped...
# Process overview: 500 pages have been scraped...
# Process overview: 510 pages have been scraped...
# https://www.winemag.com/buying-guide/domaines-schlumberger-2014-saering-grand-cru-riesling-alsace/ request failed! Status code: 502. Skip it.
# Process overview: 520 pages have been scraped...
# Process overview: 530 pages have been scraped...
# https://www.winemag.com/buying-guide/mirror-2013-cabernet-sauvignon-oak-knoll-district/ request failed! Status code: 502. Skip it.
# Process overview: 540 pages have been scraped...
# Process overview: 550 pages have been scraped...
# Process overview: 560 pages have been scraped...
# Process overview: 570 pages have been scraped...
# https://www.winemag.com/buying-guide/robert-mondavi-2013-to-kalon-vineyard-50th-anniversary-reserve-cabernet-sauvignon-oakville/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/falcone-2013-mias-vineyard-cabernet-sauvignon-paso-robles/ request failed! Status code: 502. Skip it.
# Process overview: 580 pages have been scraped...
# Process overview: 590 pages have been scraped...
# Process overview: 600 pages have been scraped...
# Process overview: 610 pages have been scraped...
# Process overview: 620 pages have been scraped...
# Page #622 request failed! Status code: 502. Skip it.
# Process overview: 630 pages have been scraped...
# https://www.winemag.com/buying-guide/loimer-2014-spiegel-reserve-gruner-veltliner-kamptal/ request failed! Status code: 502. Skip it.
# Process overview: 640 pages have been scraped...
# Process overview: 650 pages have been scraped...
# Process overview: 660 pages have been scraped...
# Process overview: 670 pages have been scraped...
# Process overview: 680 pages have been scraped...
# https://www.winemag.com/buying-guide/chateau-malartic-lagraviere-2014-barrel-sample-red-pessac-leognan/ request failed! Status code: 502. Skip it.
# Process overview: 690 pages have been scraped...
# Process overview: 700 pages have been scraped...
# https://www.winemag.com/buying-guide/rivetto-2010-del-comune-serralunga-dalba-nebbiolo-barolo/ request failed! Status code: 502. Skip it.
# Process overview: 710 pages have been scraped...
# Process overview: 720 pages have been scraped...
# https://www.winemag.com/buying-guide/penfolds-2009-rwt-shiraz-syrah-shiraz-barossa-valley/ request failed! Status code: 502. Skip it.
# Process overview: 730 pages have been scraped...
# Process overview: 740 pages have been scraped...
# Process overview: 750 pages have been scraped...
# Process overview: 760 pages have been scraped...
# Process overview: 770 pages have been scraped...
# Process overview: 780 pages have been scraped...
# Process overview: 790 pages have been scraped...
# Process overview: 800 pages have been scraped...
# https://www.winemag.com/buying-guide/trione-2007-block-twenty-one-cabernet-sauvignon-sonoma-alexander-valley/ request failed! Status code: 502. Skip it.
# Process overview: 810 pages have been scraped...
# https://www.winemag.com/buying-guide/sheldon-2009-ripken-vineyard-spanish-red-graciano-central-valley-lodi/ request failed! Status code: 502. Skip it.
# Process overview: 820 pages have been scraped...
# https://www.winemag.com/buying-guide/gaja-2006-conteisa-nebbiolo-langhe/ request failed! Status code: 502. Skip it.
# Process overview: 830 pages have been scraped...
# https://www.winemag.com/buying-guide/sanguis-2005-kubernetes-shiraz-syrah-syrah-other/ request failed! Status code: 502. Skip it.
# Process overview: 840 pages have been scraped...
# Process overview: 850 pages have been scraped...
# https://www.winemag.com/buying-guide/chateau-cheval-blanc-2009-barrel-sample-red-saint-emilion/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/chateau-sigalas-rabaud-2009-barrel-sample-white-sauternes/ request failed! Status code: 502. Skip it.
# Process overview: 860 pages have been scraped...
# https://www.winemag.com/buying-guide/rochioli-2008-estate-grown-chardonnay-sonoma-russian-river-valley/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/kendall-jackson-2005-stature-red-napa-valley/ request failed! Status code: 502. Skip it.
# Process overview: 870 pages have been scraped...
# https://www.winemag.com/buying-guide/ehret-2006-bellas-blend-red-sonoma-knights-valley/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/quinta-vesuvio-2007-vintage-port-blend-port-port/ request failed! Status code: 502. Skip it.
# Process overview: 880 pages have been scraped...
# https://www.winemag.com/buying-guide/w-j-grahams-2007-vintage-port-blend-port-port/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/bruno-paillard-1996-blanc-blancs-brut-chardonnay-champagne/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/prager-2007-wachstum-bodenstein-smaragd-riesling-wachau/ request failed! Status code: 502. Skip it.
# Process overview: 890 pages have been scraped...
# Process overview: 900 pages have been scraped...
# Process overview: 910 pages have been scraped...
# Process overview: 920 pages have been scraped...
# Process overview: 930 pages have been scraped...
# https://www.winemag.com/buying-guide/chateau-leoville-barton-2004-red-saint-julien/ request failed! Status code: 502. Skip it.
# Process overview: 940 pages have been scraped...
# Process overview: 950 pages have been scraped...
# https://www.winemag.com/buying-guide/casanova-neri-2000-cerretalto-sangiovese-brunello-montalcino/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/leonetti-cellar-2002-reserve-red-columbia-valley-walla-walla-wa/ request failed! Status code: 502. Skip it.
# Process overview: 960 pages have been scraped...
# Process overview: 970 pages have been scraped...
# Process overview: 980 pages have been scraped...
# https://www.winemag.com/buying-guide/chateau-certan-de-may-de-certan-2019-barrel-sample-pomerol/ request failed! Status code: 502. Skip it.
# Process overview: 990 pages have been scraped...
# For base url: https://www.winemag.com/?s=&rating=94.0-97.99&drink_type=wine&page=1&search_type=reviews
# Scraping has been done in 10h 32min 3s. Congrats!
# Begin scraping from base url: https://www.winemag.com/?s=&rating=80.0-82.99&drink_type=wine&page=1&search_type=reviews
# Process overview: 10 pages have been scraped...
# https://www.winemag.com/buying-guide/fulkerson-2018-estate-grown-albarino-seneca-lake/ request failed! Status code: 502. Skip it.
# Process overview: 20 pages have been scraped...
# https://www.winemag.com/buying-guide/alma-negra-2016-m-red-mendoza/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/cathedral-ridge-2014-reserve-cabernet-sauvignon-columbia-valley-or/ request failed! Status code: 502. Skip it.
# Process overview: 30 pages have been scraped...
# https://www.winemag.com/buying-guide/pradorey-2013-el-cuentista-tempranillo-blanco-vino-de-mesa/ request failed! Status code: 502. Skip it.
# Process overview: 40 pages have been scraped...
# https://www.winemag.com/buying-guide/alta-vista-2015-malbec-rose-mendoza/ request failed! Status code: 502. Skip it.
# Process overview: 50 pages have been scraped...
# https://www.winemag.com/buying-guide/voss-2014-sauvignon-blanc-napa-yountville/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/ideology-cellars-2012-proprietary-blend-red-blend-syrah-cabernet-sauvignon-napa-valley/ request failed! Status code: 502. Skip it.
# Process overview: 60 pages have been scraped...
# Process overview: 70 pages have been scraped...
# Page #80 request failed! Status code: 404. Skip it.
# Process overview: 80 pages have been scraped...
# https://www.winemag.com/buying-guide/ascension-cellars-2010-dalliance-rhone-style-red-blend-g-s-m-central-coast-paso-robles/ request failed! Status code: 502. Skip it.
# Process overview: 90 pages have been scraped...
# https://www.winemag.com/buying-guide/ampelos-2008-rho-pinot-noir-central-coast-sta-rita-hills/ request failed! Status code: 502. Skip it.
# Process overview: 100 pages have been scraped...
# Process overview: 110 pages have been scraped...
# Process overview: 120 pages have been scraped...
# Page #129 request failed! Status code: 404. Skip it.
# Process overview: 130 pages have been scraped...
# https://www.winemag.com/buying-guide/echelon-2010-red-other/ request failed! Status code: 502. Skip it.
# Process overview: 140 pages have been scraped...
# https://www.winemag.com/buying-guide/jettlynn-2007-estate-petite-sirah-central-coast-paso-robles/ request failed! Status code: 502. Skip it.
# Process overview: 150 pages have been scraped...
# https://www.winemag.com/buying-guide/pomar-junction-2009-pinot-noir-central-coast-paso-robles/ request failed! Status code: 502. Skip it.
# Process overview: 160 pages have been scraped...
# https://www.winemag.com/buying-guide/mount-baker-2007-late-harvest-viognier-columbia-valley-yakima/ request failed! Status code: 502. Skip it.
# Process overview: 170 pages have been scraped...
# https://www.winemag.com/buying-guide/fog-head-2008-reserve-chardonnay-central-coast-monterey/ request failed! Status code: 502. Skip it.
# Process overview: 180 pages have been scraped...
# Process overview: 190 pages have been scraped...
# Process overview: 200 pages have been scraped...
# https://www.winemag.com/buying-guide/wild-oak-by-st-francis-2007-chardonnay-sonoma-county/ request failed! Status code: 502. Skip it.
# Process overview: 210 pages have been scraped...
# https://www.winemag.com/buying-guide/malibu-2007-shiraz-syrah-syrah-other/ request failed! Status code: 502. Skip it.
# Process overview: 220 pages have been scraped...
# https://www.winemag.com/buying-guide/7-heavenly-chards-2007-chardonnay-central-valley-lodi/ request failed! Status code: 502. Skip it.
# Process overview: 230 pages have been scraped...
# https://www.winemag.com/buying-guide/baywood-2006-vineyard-select-other-white-symphony-other/ request failed! Status code: 502. Skip it.
# Process overview: 240 pages have been scraped...
# Process overview: 250 pages have been scraped...
# Process overview: 260 pages have been scraped...
# Process overview: 270 pages have been scraped...
# https://www.winemag.com/buying-guide/chateau-julien-2005-barrel-aged-cabernet-sauvignon-central-coast-monterey-county/ request failed! Status code: 502. Skip it.
# Process overview: 280 pages have been scraped...
# https://www.winemag.com/buying-guide/chilensis-2005-chardonnay-central-valley/ request failed! Status code: 502. Skip it.
# Process overview: 290 pages have been scraped...
# Process overview: 300 pages have been scraped...
# https://www.winemag.com/buying-guide/field-stone-2003-merlot-sonoma-alexander-valley/ request failed! Status code: 502. Skip it.
# Process overview: 310 pages have been scraped...
# Process overview: 320 pages have been scraped...
# https://www.winemag.com/buying-guide/vino-con-brio-2002-vibrante-red-blend-central-valley-lodi/ request failed! Status code: 502. Skip it.
# Page #329 request failed! Status code: 404. Skip it.
# Page #330 request failed! Status code: 404. Skip it.
# Process overview: 330 pages have been scraped...
# Page #331 request failed! Status code: 404. Skip it.
# Page #332 request failed! Status code: 404. Skip it.
# Process overview: 340 pages have been scraped...
# Process overview: 350 pages have been scraped...
# https://www.winemag.com/buying-guide/esser-cellars-2003-chardonnay-other/ request failed! Status code: 502. Skip it.
# https://www.winemag.com/buying-guide/berberana-2002-vina-alarde-tempranillo-rioja/ request failed! Status code: 502. Skip it.
# Process overview: 360 pages have been scraped...
# Process overview: 370 pages have been scraped...
# https://www.winemag.com/buying-guide/patritti-nv-shargren-sparkling-south/ request failed! Status code: 502. Skip it.
# Process overview: 380 pages have been scraped...
# Process overview: 390 pages have been scraped...
# Process overview: 400 pages have been scraped...
# https://www.winemag.com/buying-guide/nugan-family-estates-2001-third-generation-chardonnay-south-eastern/ request failed! Status code: 502. Skip it.
# Process overview: 410 pages have been scraped...
# Process overview: 420 pages have been scraped...
# Process overview: 430 pages have been scraped...
# Some items are missed from page 434: https://www.winemag.com/?s=&rating=80.0-82.99&drink_type=wine&page=434&search_type=reviews. Skip it.
# For base url: https://www.winemag.com/?s=&rating=80.0-82.99&drink_type=wine&page=1&search_type=reviews
# Scraping has been done in 4h 55min 6s. Congrats!
# Begin scraping from base url: https://www.winemag.com/?s=&rating=90.0-93.99&price=16.0-25.99,26.0-40.99&drink_type=wine&page=1&search_type=reviews
# Process overview: 10 pages have been scraped...
# Process overview: 20 pages have been scraped...
# Process overview: 30 pages have been scraped...
# https://www.winemag.com/buying-guide/acquiesce-2020-estate-grenache-blanc-lodi/ request failed! Status code: 502. Skip it.
# Process overview: 40 pages have been scraped...
# Process overview: 50 pages have been scraped...
# Process overview: 60 pages have been scraped...
# Page #68 request failed! Status code: 502. Skip it.
# Process overview: 70 pages have been scraped...
# Page #80 request failed! Status code: 404. Skip it.
# Process overview: 80 pages have been scraped...
# Process overview: 90 pages have been scraped...
# Process overview: 100 pages have been scraped...
# https://www.winemag.com/buying-guide/derby-2019-derby-vineyard-viognier-paso-robles/ request failed! Status code: 502. Skip it.
# Process overview: 110 pages have been scraped...
# Process overview: 120 pages have been scraped...
# Process overview: 130 pages have been scraped...
# Process overview: 140 pages have been scraped...
# https://www.winemag.com/buying-guide/marietta-cellars-2018-arme-estate-grown-cabernet-sauvignon-north-coast/ request failed! Status code: 502. Skip it.

# %%
df
